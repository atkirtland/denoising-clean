# %% [markdown]
# # Old Visualizations
#
# ## RIPS AFRL 2020
#
# ## Version August 19, 2020
#
#
# These visualizations may have been constructed from old or partially incorrect data, or many have just been superseded by newer visualizations present in the `visualizations.ipynb` file.

# %% [markdown]
# ## Dimension 5, timestep 1 convergence analysis - old; this is without the changed procedure, and is likely on X reconstructing Y instead of Z

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-17", "dim5_timestep1.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

# %%
points = np.log10(points)

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*points))
fig, ax = plt.subplots(facecolor='w')
ax.plot(*zip(*points), '.')
# ax.plot(points[:, 0], intercept + slope*points[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(4.0, 0.9, text)
ax.set_xlabel("Log10 of Training Time")
ax.set_ylabel("Log10 of RMSE")
ax.set_title("Dim 5, Timestep 1")
plt.show()

# %% [markdown]
# ## Dimension 2, timestep 2 convergence anlysis; the same caveats apply as they did above.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-17", "dim2_timestep2.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-3])])
points = np.array(points)

# %%
points = np.log10(points)

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*points))
fig, ax = plt.subplots(facecolor='w')
ax.plot(*zip(*points), '.')
# ax.plot(points[:, 0], intercept + slope*points[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.5, -2, text)
ax.set_xlabel("Log10 Training Time")
ax.set_ylabel("Log10 RMSE")
ax.set_title("Dim 2, Timestep 2, Tau 2")
plt.show()

# %% [markdown]
# ### This was supposed to be a log-log plot comparing the performance with different values of $d$. This isn't really the behavior we would expect now, so something may be wrong with it. We will include it because it demonstrates how to show four plots at once.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-21", "four_dims.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

# %%
points = np.log10(points)

# %%
ptsgrplen = len(points)//4
fig, axs = plt.subplots(2, 2)
axs[0,0].plot(*zip(*points[0:ptsgrplen]), '.')
axs[0,1].plot(*zip(*points[ptsgrplen:2*ptsgrplen]), '.')
axs[1,0].plot(*zip(*points[2*ptsgrplen:3*ptsgrplen]), '.')
axs[1,1].plot(*zip(*points[3*ptsgrplen:]), '.')

axs[0,0].set_xlabel("Log10 Training Time")
axs[0,0].set_ylabel("Log10 RMSE")
axs[0,0].set_title("Dim 2")
axs[0,1].set_xlabel("Log10 Training Time")
axs[0,1].set_ylabel("Log10 RMSE")
axs[0,1].set_title("Dim 3")
axs[1,0].set_xlabel("Log10 Training Time")
axs[1,0].set_ylabel("Log10 RMSE")
axs[1,0].set_title("Dim 4")
axs[1,1].set_xlabel("Log10 Training Time")
axs[1,1].set_ylabel("Log10 RMSE")
axs[1,1].set_title("Dim 5")

plt.show()

# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*points))
# fig, ax = plt.subplots(facecolor='w')
# ax.plot(*zip(*points), '.')
# ax.plot(points[:, 0], intercept + slope*points[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.5, -2, text)

# %% [markdown]
# ### These plots are similar.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-21", "four_dims_lin_interpolation.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

# %%
points = np.log10(points)

# %%
ptsgrplen = len(points)//4
fig, axs = plt.subplots(2, 2)
axs[0,0].plot(*zip(*points[0:ptsgrplen]), '.')
axs[0,1].plot(*zip(*points[ptsgrplen:2*ptsgrplen]), '.')
axs[1,0].plot(*zip(*points[2*ptsgrplen:3*ptsgrplen]), '.')
axs[1,1].plot(*zip(*points[3*ptsgrplen:]), '.')

axs[0,0].set_xlabel("Log10 Training Time")
axs[0,0].set_ylabel("Log10 RMSE")
axs[0,0].set_title("Dim 2")
axs[0,1].set_xlabel("Log10 Training Time")
axs[0,1].set_ylabel("Log10 RMSE")
axs[0,1].set_title("Dim 3")
axs[1,0].set_xlabel("Log10 Training Time")
axs[1,0].set_ylabel("Log10 RMSE")
axs[1,0].set_title("Dim 4")
axs[1,1].set_xlabel("Log10 Training Time")
axs[1,1].set_ylabel("Log10 RMSE")
axs[1,1].set_title("Dim 5")

plt.show()

# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*points))
# fig, ax = plt.subplots(facecolor='w')
# ax.plot(*zip(*points), '.')
# ax.plot(points[:, 0], intercept + slope*points[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.5, -2, text)

# %% [markdown]
# ### This plot compared the log-log curve when using just linear interpolation with an unknown triangulation vs. using (linear) interpolation with the Delaunay triangulation.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-24", "lin-vs-delaunay.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

pointsa = points[0:30]
ax.plot(*zip(*pointsa), 'r.')
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
print(slope)

pointsb = points[30:60]
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(*zip(*pointsb), 'b.')
ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.5, -2, text)
print(slope)
ax.set_xlabel("Log10 Training Time")
ax.set_ylabel("Log10 RMSE")
# ax.set_title("Dim 2, Timestep 2, Tau 2")
plt.show()
# Out:
# -0.2672759358794589
# -0.27279194767199144

# %% [markdown]
# ### This histogram shows the bin counts of the unstructured mesh without $k$-means

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []

bin_counts = np.loadtxt(os.path.join("results", "7-24", "bin_counts100mil.txt"))

# for uniform
bin_counts = [c for c in bin_counts if c > 10 and c < 45000]

# %%
max(bin_counts)
# Out:
# 44986.0

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []

bin_counts = np.loadtxt(os.path.join("results", "7-24", "bin_counts100mil.txt"))

print(sum([i for i in bin_counts]))

# for uniform
# bin_counts = [c for c in bin_counts if c > 10 and c < 45000]

import scipy.stats as stats  
fit_alpha, fit_loc, fit_beta=stats.gamma.fit(bin_counts)
print(fit_alpha, fit_loc, fit_beta)
fig, ax = plt.subplots(facecolor='w')
x = range(0, 50000)
ax.plot(x, 8300000*stats.gamma.pdf(x, a=fit_alpha, loc=fit_loc, scale=fit_beta))
ax.hist(bin_counts, 50)
ax.set_xlabel("Bin Count")
ax.set_ylabel("Frequency")
ax.set_title("Unstructured Mesh Bin Counts\nHistogram and Gamma Distribution")
# text = "alpha: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(4.0, 0.9, text)
plt.show()
# Out:
# 99900000.0
# 3.653685194797995 -299.50000235419066 3845.0132045227283

# %% [markdown]
# ### This histogram shows the same thing, but for the uniform mesh.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []

bin_counts = np.loadtxt(os.path.join("results", "7-24", "bin_counts_uniform_100mil.txt"))

print(sum([i for i in bin_counts]))

# for uniform
bin_counts = [c for c in bin_counts if c > 0]

import scipy.stats as stats  
fit_alpha, fit_loc, fit_beta=stats.gamma.fit(bin_counts)
print(fit_alpha, fit_loc, fit_beta)
fig, ax = plt.subplots(facecolor='w')
x = range(0, 50000)
# ax.plot(x, 8000000*stats.gamma.pdf(x, a=fit_alpha, loc=fit_loc, scale=fit_beta))
ax.hist(bin_counts, 40)
ax.set_xlabel("Bin Count")
ax.set_ylabel("Frequency")
ax.set_title("Uniform Mesh Bin Counts\nHistogram")
# text = "alpha: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(4.0, 0.9, text)
plt.show()
# Out:
# 99900000.0
# 0.0001438841173655982 0.9999999999999999 4.336942795325049

# %% [markdown]
# ### Uniform Loglog

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-27", "uniform_loglog.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)
points = np.log10(points)
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*points))
fig, ax = plt.subplots(facecolor='w')
ax.plot(*zip(*points), '.')
ax.plot(points[:, 0], intercept + slope*points[:, 0], '-')
text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
ax.text(4.0, 0.1, text)
ax.set_xlabel("Log10 of Training Time")
ax.set_ylabel("Log10 of RMSE")
ax.set_title("Uniform Grid\n Dimension 2, Timestep 0.01, Tau 0.1")
plt.show()

# %% [markdown]
# ### Uniform vs Unstructured Loglog Comparison - something may be wrong here, again

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-27", "uniform_dim3_xz_thickermesh.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

slopes = []

pointsa = points[0:20]
ax.plot(*zip(*pointsa), 'r.')
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
# text = "Slope: "+str(round(slope, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.0, 0.45, text)
slopes.append(slope)

pointsb = points[20:40]
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(*zip(*pointsb), 'b.')
ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], 'b-')
# text = "Slope: "+str(round(slope, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.65, text)
slopes.append(slope)


pointsa = points[40:60]
ax.plot(*zip(*pointsa), 'g.')
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'g-')
# text = "Slope: "+str(round(slope, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.0, 0.45, text)
slopes.append(slope)


pointsb = points[60:80]
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(*zip(*pointsb), 'y.')
ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], 'y-')
# text = "Slope: "+str(round(slope, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.65, text)
slopes.append(slope)

ax.set_xlabel("Log10 Training Time")
ax.set_ylabel("Log10 RMSE")
ax.set_title("Uniform Grid vs Unstructured Grid\nX Reconstructing Z, Timestep 0.01, Tau 0.1")

ax.legend(["Uniform Dimension 2", "Slope: "+str(round(slopes[0], 3)), 
           "Uniform Dimension 3", "Slope: "+str(round(slopes[1], 3)),
           "Unstructured Dimension 2", "Slope: "+str(round(slopes[2], 3)),
           "Unstructured Dimension 3", "Slope: "+str(round(slopes[3], 3))])
plt.show()

# %% [markdown]
# ### This is a weird plot we got at one point for the uniform mesh.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
points = []
with open(os.path.join("results", "7-30", "uniform_fixedsubset.csv"), "r") as f:
    reader = csv.reader(f)
    for row in reader:
        points.append([float(row[0]), float(row[-1])])
points = np.array(points)

points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

pointsa = points[0:10]
ax.plot(*zip(*pointsa), 'r.')
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.5, -0.3, text)

pointsb = points[10:20]
slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(*zip(*pointsb), 'b.')
ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], '-')
text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.1, text)

ax.set_xlabel("Log10 Training Time")
ax.set_ylabel("Log10 RMSE")
ax.set_title("Uniform Mesh with and without Linear Interpolation\nX reconstructing Z, Epsilon 2,  Dim 2, Timestep 0.01, Tau 0.1")

ax.legend(["", "With Interpolation", "", "Without"])
plt.show()

# %% [markdown]
# ### This next few graphs are error comparison plots.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
# points = []
# with open(os.path.join("results", "7-30", "uniform_fixedsubset.csv"), "r") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         points.append([float(row[0]), float(row[-1])])
# points = np.array(points)

# points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

errs = [10**(-n) for n in range(10)]
a = [0.9251275336422599, 0.9739722405691749, 0.9855390712608975, 0.9898827554660247, 0.9906003767839483, 0.9902699558845859, 0.9888777759295956, 0.9910162564654674, 0.9919791372142851]
b = [0.934537799148558, 0.9681962212521128, 0.9790844703648224, 0.9799575067903921, 0.9817348446737093, 0.9829214897252181, 0.9821295815053089, 0.9820715703055054, 0.9812358674661136, 0.9811223681322238]

errs = np.array(errs)
a = np.array(a)
b = np.array(b)

base = 2
errs = np.log(errs)/np.log(base)
a = np.log(a)/np.log(base)
b = np.log(b)/np.log(base)

# pointsa = points[0:10]
ax.plot(1-errs[1:], 1-a, 'r.')
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
# ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.5, -0.3, text)

# pointsb = points[10:20]
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(1-errs, 1-b, 'b.')
# ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.1, text)

ax.set_xlabel("Log2 of 1 - Scale")
ax.set_ylabel("Log2 of 1 - PCC")
ax.set_title("PCC vs Scale")

ax.legend(["0 Error vs ", "With Interpolation"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
# points = []
# with open(os.path.join("results", "7-30", "uniform_fixedsubset.csv"), "r") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         points.append([float(row[0]), float(row[-1])])
# points = np.array(points)

# points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

errs = [8*2**(-n) for n in range(10)]
a = [0.634984701104341, 0.8499230037892419, 0.9537644421782088, 0.9810793107952832, 0.9903830791305341, 0.9928606360870863, 0.9935404884411598, 0.9927630857817822, 0.9936602071763692, 0.9938708587945024]
b = [0.6362221836321984, 0.8425176620665222, 0.9476045275426036, 0.9780857539544516, 0.9848185910176637, 0.9894831084437102, 0.9896484052337118, 0.9897205589517082, 0.9903809822170453, 0.9888234114415143]
c = [0.634984701104341, 0.5185546937021416, 0.8156744742011648, 0.9427460458683764, 0.9769731528260884, 0.9899930340928985, 0.9925728202570068, 0.99296125624264, 0.9931631385333072, 0.9929359519673914]


errs = np.array(errs)
a = np.array(a)
b = np.array(b)
c = np.array(c)

a = 1 - a
b = 1 - b
c = 1 - c

base = 2
errs = np.log(errs)/np.log(base)
a = np.log(a)/np.log(base)
b = np.log(b)/np.log(base)
c = np.log(c)/np.log(base)

errs = 1 - errs


# pointsa = points[0:10]
ax.plot(errs, a, 'r.')
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
# ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.5, -0.3, text)

# pointsb = points[10:20]
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(errs, b, 'b.')
# ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.1, text)

# ax.plot(errs[:-1], c, 'g.')

ax.set_xlabel("1 - Log2 Scale")
ax.set_ylabel("Log2 of 1 - PCC")
ax.set_title("PCC vs Scale")

ax.legend(["0 vs Scale Error Reconstruction", 
           "Original vs Scale Error Reconstruction",
#           "Scale vs Next Scale Error Reconstruction"
          ])
plt.show()

# %% [markdown]
# ### The next few plots are uniform vs unstructured comparison plots.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

# unif_pts = []
# vor_pts = []

points = []
pts2 = []

with open(os.path.join("results", "8-11", "equal_nonempty2.csv"), "r") as f:
    reader = csv.reader(f)
#     next(reader)
#     i = 0
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
#         if i == 0:
#             unif_pts.append(pt)
#         elif i == 1:
#             vor_pts.append(pt)
#         i = (i + 1) % 2
    
points = np.array(points)
pts2 = np.array(pts2)
# points = np.log10(points)



unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
#                        sharex=True, sharey=True
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nLinear interpolation")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nLinear interpolation")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')


plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-11", "equal_nonempty_nointerpolation.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nNo interpolation")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nNo interpolation")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-12", "scaled-subset-sizes.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nScaled Subset Sizes")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-12", "scaled-subset-sizes_but_lin.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nScaled Subset Sizes")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-12", "scaled-subset-sizes_but_lin2d.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nScaled Subset Sizes but Linear Interpolation in 2D")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes but Linear Interpolation 2D")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-12", "scaled-subset-sizes_but_del.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nScaled Subset Sizes but Delaunay Interpolation")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes but Delaunay Interpolation")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
pts2 = []

with open(os.path.join("results", "8-12", "scaled-subset-sizes_but_nn.csv"), "r") as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[16])), # number nonempty
              np.log10(1-float(row[19])), # pcc
             ]
        pt2 = [
            np.log10(float(row[16])), # number nonempty
                          np.log10(float(row[17])), # time
             ]
        points.append(pt)
        pts2.append(pt2)
    
points = np.array(points)
pts2 = np.array(pts2)

unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 2, facecolor='w', figsize=(15, 15)
                      )

ax[0].plot(*zip(*unif_pts), 'r.')
ax[0].plot(*zip(*vor_pts), 'b.')

ax[1].plot(*zip(*unif_pts2), 'r.')
ax[1].plot(*zip(*vor_pts2), 'b.')


ax[0].set_xlabel("Log10 of Nonempty Subset Size")
ax[0].set_ylabel("Log10 of 1 - PCC")
ax[0].set_title("Comparison of PCC for fixed nonempty subset size\nScaled Subset Sizes but NN Interpolation")

ax[1].set_xlabel("Log10 of Nonempty Subset Size")
ax[1].set_ylabel("Log10 of Time of Experiment")
ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes but NN Interpolation")

ax[0].set(adjustable='box', aspect='equal')
ax[1].set(adjustable='box', aspect='equal')

plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %% [markdown]
# ## This shows how the loglog HET plot breaks with a certain subset size. There are other files in 8-14 that have similar data, but for different subset size, if you are interested in comparing them.

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os

points = []
# pts2 = []

# with open(os.path.join("results", "8-13", "scaled-subset-sizes_comparison_optimalvor.csv"), "r") as f:
# with open(os.path.join("results", "8-14", "het_conv_0error.csv"), "r") as f:
with open(os.path.join("results", "8-14", "het_conv_0error_subset100_tau20_dim30.csv"), "r") as f:


    reader = csv.reader(f)
    next(reader)
    for row in reader:
        pt = [np.log10(float(row[6])), # number nonempty
              np.log10(1-float(row[-1])), # pcc
             ]
#         pt2 = [
#             np.log10(float(row[16])), # number nonempty
#                           np.log10(float(row[17])), # time
#              ]
        points.append(pt)
#         pts2.append(pt2)
    
points = np.array(points)
# pts2 = np.array(pts2)

# unif_pts = [points[i] for i in range(len(points)) if i % 2 == 0]
# vor_pts = [points[i] for i in range(len(points)) if i % 2 == 1]
# unif_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 0]
# vor_pts2 = [pts2[i] for i in range(len(points)) if i % 2 == 1]


from scipy import stats
fig, ax = plt.subplots(1, 1, facecolor='w'
                      )

ax.plot(*zip(*points), 'r.', markersize=10)
# ax[0].plot(*zip(*points), 'b.')

# ax[1].plot(*zip(*unif_pts2), 'r.')
# ax[1].plot(*zip(*vor_pts2), 'b.')


ax.set_xlabel("Log10 of Training Size")
ax.set_ylabel("Log10 of 1 - PCC")
ax.set_title("PCC vs Training Size\nHET Anode+Cathode Reconstructing HET Cathode Pearson")

# ax[1].set_xlabel("Log10 of Nonempty Subset Size")
# ax[1].set_ylabel("Log10 of Time of Experiment")
# ax[1].set_title("Comparison of Time for fixed nonempty subset size\nScaled Subset Sizes but NN Interpolation")

# ax[0].set(adjustable='box', aspect='equal')
# ax[1].set(adjustable='box', aspect='equal')

# plt.legend(["Uniform Mesh", "Unstructured Mesh"])
plt.show()

# %% [markdown]
# ## Here is another error analysis plot

# %%
import csv
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import os
# points = []
# with open(os.path.join("results", "7-30", "uniform_fixedsubset.csv"), "r") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         points.append([float(row[0]), float(row[-1])])
# points = np.array(points)

# points = np.log10(points)

from scipy import stats
fig, ax = plt.subplots(facecolor='w')

errs = [8*2**(-n) for n in range(10)]
a = [0.24789758915073523, 0.5125429333041184, 0.6153323586072846, 0.8917929509296015, 0.9664182943775953, 0.9852158004014662, 0.9890545387052674, 0.992326072591854, 0.9910985357409456, 0.9920947525584578]
b = [0.2390661897173953, 0.5154766056238689, 0.6191176177681685, 0.8878416176331617, 0.9625724373244076, 0.9828587848678118, 0.9872112887638355, 0.9881036712037896, 0.9902001254783097, 0.9891054486444221]
c = [0.24789758915073523, 0.23105022951561904, 0.3231326609919904, 0.5908955840846479, 0.8673802821857876, 0.9615991493684444, 0.9854949949453073, 0.9906618348440424, 0.9924180102619317, 0.993141870186058]


errs = np.array(errs)
a = np.array(a)
b = np.array(b)
c = np.array(c)

a = 1 - a
b = 1 - b
c = 1 - c

base = 2
errs = np.log(errs)/np.log(base)
a = np.log(a)/np.log(base)
b = np.log(b)/np.log(base)
c = np.log(c)/np.log(base)

errs = 1 - errs


# pointsa = points[0:10]
ax.plot(errs, a, 'r.')
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsa))
# ax.plot(pointsa[:, 0], intercept + slope*pointsa[:, 0], 'r-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(2.5, -0.3, text)

# pointsb = points[10:20]
# slope, intercept, r_value, p_value, std_err = stats.linregress(*zip(*pointsb))
ax.plot(errs, b, 'b.')
# ax.plot(pointsb[:, 0], intercept + slope*pointsb[:, 0], '-')
# text = "Slope: "+str(round(slope, 3))+"\nIntercept: "+str(round(intercept, 3))+"\nR^2: "+str(round(r_value**2, 3))
# ax.text(3.0, 0.1, text)

# ax.plot(errs[:-1], c, 'g.')

ax.set_xlabel("1 - Log2 σ")
ax.set_ylabel("Log2 of 1 - PCC")
ax.set_title("PCC vs Scale σ\n Training Set Size: 10000 points")

ax.legend(["No Noise vs N(0,σ) Noise Reconstructions", 
           "Original vs N(0,σ) Noise Reconstruction",
#           "Scale vs Next Scale Error Reconstruction"
          ])
plt.show()

# %%
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import os
import numpy as np

data = pd.read_csv(os.path.join("results", "8-18", "subsetplots.csv")) 

fig, ax = plt.subplots()
plt.plot(np.log10(data["training_size"].values[:100]), np.log10(1-data["pcc"].values[:100]), '.')
plt.show()

# %% [markdown]
# # Lorenz96 Visualizaton

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

# These are our constants
N = 50  # Number of variables
F = 8  # Forcing

# d = np.empty(N)

# @jit
def lorenz96(x, t):
    """Lorenz 96 model."""
    # Compute state derivatives
    d = np.empty(N)
    for i in range(N):
        d[i] = (x[(i+1) % N] - x[(i-2) % N]) * x[(i-1) % N] - x[i]
    d = d + F

    # Return the state derivatives
    return d

x0 = F * np.random.normal(size=N)  # Initial state (equilibrium)
# x0[19] += 0.01  # Add small perturbation to 20th variable
t = np.arange(0.0, 100.0, 0.01)

data = odeint(lorenz96, x0, t)

# Plot the first three variables
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(data[:, 0], data[:, 1], data[:, 2])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
plt.show()

# %% [markdown]
# ## Old: This AMI code was translated into Python from the 2019 team's Matlab Code from a professor. It is rather slow, and we think and hope that the code above does the same thing.

# %%
X = data2[:,0]

lags = range(0, 10)
n = len(X)
x = (X - min(X))/(max(X)-min(X))

amis = []

for lag in lags:
    ami = 0.0

    nbins = int(np.floor(1 + np.log2(n - lag) + 0.5))
#     pij = np.zeros((nbins, nbins))
#     pi = np.zeros((nbins,))
#     pj = np.zeros((nbins,))
    
#     x2 = np.floor(x*nbins).astype(int)
#     for i in range(len(x2)):
#         if x2[i] == nbins:
#             x2[i] -= 1
#     print(x2)
    
#     for i in range(len(x)-lag):
#         pij[x2[i], x2[i+lag]] += 1
#         pi[x2[i]] += 1
#         pj[x2[i+lag]] += 1
    
#     pij /= len(x)-lag
#     pi /= len(x)-lag
#     pj /= len(x)-lag
    
    for i in range(1, nbins+1):
        for j in range(1, nbins+1):
            pii = [a for a in x if a > (i-1)/nbins and a <= i/nbins and (j-1)/nbins < a and a <= j/nbins]
            px1 = [a for a in x if (i-1)/nbins < a and a <= j/nbins]
            px2 = [a for a in x if (j-1)/nbins < a and a <= j/nbins]
            if len(pii) > 0:
                pii = len(pii) / (n-lag)
                px1 = len(px1) / (n-lag)
                px2 = len(px2) / (n-lag)
                ami += pii*np.log2(pii/(px1*px2))
#                 ami += pij[i, j] * np.log2(pij[i, j] / (pi[i] * pj[j]))
    
    amis.append(ami)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1fdaf45a8e0a> in <module>()
# ----> 1 X = data2[:,0]
#       2
#       3 lags = range(0, 10)
#       4 n = len(X)
#       5 x = (X - min(X))/(max(X)-min(X))
#
# NameError: name 'data2' is not defined
